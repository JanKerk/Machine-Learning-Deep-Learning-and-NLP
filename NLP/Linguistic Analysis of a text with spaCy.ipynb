# %% [markdown]
# ## Goal was to do an linguistic analysis of a text with spaCy, making use of POS tagging and NER

# %%
import re
import spacy
from spacy import displacy
import nltk
from nltk.corpus import stopwords
from prettytable import PrettyTable
from collections import Counter

# %% [markdown]
# ## Clean Corpus

# %%
# Get the corpus
with open("sample.txt", "r", encoding="utf-8") as file:
    text = file.read()  # Reads the entire file

# Remove Illustrations comments
text = re.sub(r'\[Illustration:.*?\]', '', text, flags=re.DOTALL).strip()

# Remove underscores around words
text = re.sub(r'([^\n]+)_', r'\1', text)

# Split text into lines
lines = text.split("\n")

# Remove the first line
lines = lines[1:]

# Remove chapter numeration (Roman numerals)
filtered_lines = []
for i, line in enumerate(lines): # Iterate over lines
    if re.match(r'^\s*[IVXLCDM]+\s*$', line):  # Check if line is only Roman numerals
        continue  # Skip only the numeration line
    filtered_lines.append(line)

text = "\n".join(filtered_lines) # Text without numeration

# Lower text
text = text.lower()

# Remove punctuation
text = re.sub(r'[^\w\s]', '', text)  # Removes all non-word characters except spaces

# Remove extra spaces
text = re.sub(r'\s+', ' ', text).strip()

# Remove stopwords
nltk.download('stopwords')  # Uncomment if running for the first time
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in text.split() if word not in stop_words]
text = ' '.join(filtered_words)
    
# Load SpaCy's English model
nlp = spacy.load("en_core_web_sm")

# Process the text with SpaCy
doc = nlp(text)

# Tokenize and normalize text
tokens = []
for token in doc:
    tokens.append(token.lemma_)  # Lemmatize

# Cleaned text
cleaned_text = " ".join(tokens)
# Out:
# [nltk_data] Downloading package stopwords to /Users/user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## POS Tagging with most common POS tags

# %%
# Process text (string) with spacy again to apply POS
doc = nlp(cleaned_text)

# POS Tagging
pos_tags = [token.pos_ for token in doc]  # Collect all POS tags

# Analysis: Determine the most common POS tags
pos_counts = Counter(pos_tags)  # Count the frequency of each POS tag
sorted_pos_counts = pos_counts.most_common()  # Sort by frequency

# Create a table to display the frequency of POS tags
pos_count_table = PrettyTable(["POS Tag", "Frequency"])
for pos, count in sorted_pos_counts:
    pos_count_table.add_row([pos, count])

print("\nMost Common POS Tags:\n", pos_count_table)
# Out:
# Most Common POS Tags:
#  +---------+-----------+
# | POS Tag | Frequency |
# +---------+-----------+
# |   NOUN  |    2593   |
# |   VERB  |    1584   |
# |   ADJ   |    1217   |
# |  PROPN  |    855    |
# |   ADV   |    641    |
# |   AUX   |    402    |
# |   PRON  |    177    |
# |   PART  |    170    |
# |   NUM   |    112    |
# |   ADP   |    108    |
# |   INTJ  |     56    |
# |  SCONJ  |     25    |
# |   DET   |     24    |
# |  CCONJ  |     8     |
# |    X    |     3     |
# +---------+-----------+

# %% [markdown]
# ## NER

# %%
# Collect labels of named entities
entities = [(ent.label_) for ent in doc.ents]

# Analysis: Determine the most common NER labels
ner_counts = Counter(entities)  # Count the frequency of each label
sorted_ner_counts = ner_counts.most_common()  # Sort by frequency

# Create a table to display the frequency of NER labels
ner_count_table = PrettyTable(["Label", "Frequency"])
for label, count in sorted_ner_counts:
    ner_count_table.add_row([label, count])

print("\nMost Common NER Labels:\n", ner_count_table)
# Out:
# Most Common NER Labels:
#  +----------+-----------+
# |  Label   | Frequency |
# +----------+-----------+
# |  PERSON  |    190    |
# | CARDINAL |     61    |
# |   DATE   |     23    |
# | ORDINAL  |     23    |
# |   TIME   |     20    |
# |   ORG    |     9     |
# |   GPE    |     1     |
# |   FAC    |     1     |
# +----------+-----------+

# %%
# Show frequency of each named entity
# Collect text and labels of named entities
entities_2 = [(ent.text, ent.label_) for ent in doc.ents]

# Analysis: Determine the most common NER labels
ner_counts_2 = Counter(entities_2)  # Count the frequency of each label
sorted_ner_counts_2 = ner_counts_2.most_common()  # Sort by frequency

# Create a table to display the frequency of NER labels
ner_count_table_2 = PrettyTable(["Text and Label", "Frequency"])
for label, count in sorted_ner_counts_2:
    ner_count_table_2.add_row([label, count])

print("\nMost Common NER Labels (with Text):\n", ner_count_table_2)
# Out:
# Most Common NER Labels (with Text):
#  +------------------------------------------------+-----------+
# |                 Text and Label                 | Frequency |
# +------------------------------------------------+-----------+
# |               ('joe', 'PERSON')                |     57    |
# |              ('one', 'CARDINAL')               |     43    |
# |            ('joe otter', 'PERSON')             |     18    |
# |              ('first', 'ORDINAL')              |     18    |
# |            ('sammy jay', 'PERSON')             |     14    |
# |              ('two', 'CARDINAL')               |     12    |
# |              ('tomorrow', 'DATE')              |     7     |
# |              ('peter', 'PERSON')               |     7     |
# |               ('bush', 'PERSON')               |     7     |
# |              ('morning', 'TIME')               |     6     |
# |          ('jerry muskrat', 'PERSON')           |     5     |
# |             ('second', 'ORDINAL')              |     5     |
# |             ('three', 'CARDINAL')              |     4     |
# |               ('today', 'DATE')                |     3     |
# |             ('joe slip', 'PERSON')             |     2     |
# |            ('joe billy', 'PERSON')             |     2     |
# |            ('next morning', 'TIME')            |     2     |
# |         ('early next morning', 'TIME')         |     2     |
# |          ('muddy place bank', 'ORG')           |     2     |
# |           ('peter rabbit', 'PERSON')           |     2     |
# |            ('joe story', 'PERSON')             |     2     |
# |           ('johnny chuck', 'PERSON')           |     2     |
# |           ('red squirrel', 'PERSON')           |     2     |
# |        ('jack gray squirrel', 'PERSON')        |     2     |
# |       ('sammy jay make great', 'PERSON')       |     2     |
# |           ('another minute', 'TIME')           |     2     |
# |               ('summer', 'DATE')               |     2     |
# |        ('first early morning', 'TIME')         |     1     |
# |             ('squirrel', 'PERSON')             |     1     |
# |            ('joe sat bank', 'ORG')             |     1     |
# |            ('bear spring', 'DATE')             |     1     |
# |           ('joe put head', 'PERSON')           |     1     |
# |             ('joe come', 'PERSON')             |     1     |
# |             ('joe turn', 'PERSON')             |     1     |
# |             ('joe tell', 'PERSON')             |     1     |
# |            ('joe otters', 'PERSON')            |     1     |
# |          ('joe come back', 'PERSON')           |     1     |
# |           ('joe fiercely', 'PERSON')           |     1     |
# |              ('joe otter', 'ORG')              |     1     |
# |        ('joe frighten drop', 'PERSON')         |     1     |
# |              ('muddy', 'PERSON')               |     1     |
# |        ('bobby farmer brown', 'PERSON')        |     1     |
# |             ('joe hell', 'PERSON')             |     1     |
# |             ('joe ill', 'PERSON')              |     1     |
# |            ('joe chase', 'PERSON')             |     1     |
# |             ('yesterday', 'DATE')              |     1     |
# |             ('joe sulk', 'PERSON')             |     1     |
# |            ('joe tickle', 'PERSON')            |     1     |
# |           ('joe chugarum', 'PERSON')           |     1     |
# |         ('joe grandfather', 'PERSON')          |     1     |
# |           ('joe foolish', 'PERSON')            |     1     |
# |            ('joe great', 'PERSON')             |     1     |
# |        ('joe disrespectful', 'PERSON')         |     1     |
# |            ('joe spoil', 'PERSON')             |     1     |
# |           ('joe sniffed', 'PERSON')            |     1     |
# |          ('joe goodnature', 'PERSON')          |     1     |
# |            ('joe mouth', 'PERSON')             |     1     |
# |            ('late morning', 'TIME')            |     1     |
# |             ('joe dart', 'PERSON')             |     1     |
# |            ('joe small', 'PERSON')             |     1     |
# |            ('joe sprang', 'PERSON')            |     1     |
# |         ('joe farmer brown', 'PERSON')         |     1     |
# |              ('next day', 'DATE')              |     1     |
# |               ('s bank', 'ORG')                |     1     |
# |                ('day', 'DATE')                 |     1     |
# |             ('joe make', 'PERSON')             |     1     |
# |        ('peter rabbit snarl', 'PERSON')        |     1     |
# |            ('one fine day', 'DATE')            |     1     |
# |          ('peter chugarum', 'PERSON')          |     1     |
# |          ('bear minute one', 'TIME')           |     1     |
# |       ('blacky crow lean perch', 'ORG')        |     1     |
# |            ('joe glare', 'PERSON')             |     1     |
# |           ('early morning', 'TIME')            |     1     |
# |    ('smile poolhow farmer brown', 'PERSON')    |     1     |
# |            ('bobby coon', 'PERSON')            |     1     |
# |             ('blacky crow', 'ORG')             |     1     |
# |            ('billy mink', 'PERSON')            |     1     |
# |          ('big green lilypad', 'ORG')          |     1     |
# |           ('danny meadow', 'PERSON')           |     1     |
# |             ('jimmy', 'CARDINAL')              |     1     |
# |           ('badger bobby', 'PERSON')           |     1     |
# |         ('sammy jay blacky', 'PERSON')         |     1     |
# |          ('sammy jay slip', 'PERSON')          |     1     |
# |         ('caw caw caw time', 'PERSON')         |     1     |
# |         ('squirrel snicker', 'PERSON')         |     1     |
# |      ('sammy jay join blacky', 'PERSON')       |     1     |
# |              ('one day', 'DATE')               |     1     |
# |               ('blacky', 'GPE')                |     1     |
# |            ('bear morning', 'TIME')            |     1     |
# |    ('jack gray squirrel cousin', 'PERSON')     |     1     |
# |      ('chatterer red squirrel', 'PERSON')      |     1     |
# |              ('bobby', 'PERSON')               |     1     |
# |    ('caw caw caw shriek blacky', 'PERSON')     |     1     |
# |   ('jack look peter rabbit peter', 'PERSON')   |     1     |
# |         ('bobby coon bobby', 'PERSON')         |     1     |
# |               ('minute', 'TIME')               |     1     |
# |             ('bear fall', 'DATE')              |     1     |
# |    ('livelong day dozen time day', 'DATE')     |     1     |
# |          ('squirrel jump', 'PERSON')           |     1     |
# |   ('bear ill teach manner ill teach', 'ORG')   |     1     |
# |             ('time year', 'DATE')              |     1     |
# |            ('sigh sigh', 'PERSON')             |     1     |
# |            ('berry lick', 'PERSON')            |     1     |
# |          ('tomorrow morning', 'TIME')          |     1     |
# |      ('sammy jay last buster', 'PERSON')       |     1     |
# |        ('early morning night', 'TIME')         |     1     |
# |              ('day old', 'DATE')               |     1     |
# |             ('lie foot', 'PERSON')             |     1     |
# |         ('slip head handle', 'PERSON')         |     1     |
# |          ('sammy morning', 'PERSON')           |     1     |
# |             ('blacky crow', 'FAC')             |     1     |
# |    ('caw caw caw come everybody', 'PERSON')    |     1     |
# |    ('sammy jay blacky crow see', 'PERSON')     |     1     |
# |              ('mistah', 'PERSON')              |     1     |
# |    ('mistah buzzard begin grin', 'PERSON')     |     1     |
# | ('kingbird redwe blackbird drummer', 'PERSON') |     1     |
# |           ('robin tommy', 'PERSON')            |     1     |
# |            ('jenny wren', 'PERSON')            |     1     |
# |   ('sammy jay blacky crow carry', 'PERSON')    |     1     |
# |           ('one tenth', 'CARDINAL')            |     1     |
# |       ('sammy jay reddy fox', 'PERSON')        |     1     |
# |       ('sammy jay come back', 'PERSON')        |     1     |
# |               ('spring', 'DATE')               |     1     |
# +------------------------------------------------+-----------+

# %%
print('\n NER with spaCy')

#function takes a doc (string) and prints NER table with all identified entities from the doc
def NER_spacy (doc):
    tab2 = PrettyTable(['Entity', 'Label'])
    for e in doc.ents:
        tab2.add_row([e.text, e.label_])

    print(tab2)

#run the language module
my_doc = nlp(cleaned_text)

displacy.render((my_doc), jupyter=True, style='ent') #this is for the colour NEW
# Out:
#  NER with spaCy
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">buster bear go fishing buster bear yawned lie comfortable bed leave watch
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first early morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  sunbeam creep green forest chase black shadow yawn slowly get foot shake walk big pinetree stand hind leg reach high trunk tree could scratched bark great claws yawned seem jaw would crack sit think want breakfast sit try make mind would taste good listening sound tell wake little people live green forest hear
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sammy jay
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  way distance scream thief thief grin wonder thought buster
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  steal sammys breakfast steal breakfast
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  else probably thief hear chatterer red
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     squirrel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  scold fast could make tongue go work terrible rage must chatterer get bed wrong way morning thought hear blacky crow caw top lung know sound blacky get mischief kind hear sweet voice happy little singer good hear listen merry low silvery laugh never stop go feel must laugh voice laugh brook buster listen suddenly come want breakfast I m go fishing say deep grumblyrumbly voice
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  particular yes sir I m going fishing want fat trout breakfast shuffle along laugh brook straight little pool know draw near take great care make teeny weeniest bit noise happen early one buster bear come sight little pool see another fisherman already catch fine fat trout little
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     joe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  otter sure climb bank fat trout mouth buster bear mouth water see little
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     joe sat bank
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  prepare enjoy breakfast have not see buster bear do not know one else anywhere near buster bear tiptoe softly right behind little
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     joe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  otter woof woof say deep grumblyrumbly voice that s fine look trout would not mind little
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     joe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  otter give frightened squeal without even turn see speaking drop fish dive headfirst laugh brook buster
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bear spring
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  forward
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  big paw catch fat trout slip back water here trout mr otter say little
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     joe put head
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  water see frightened come get little
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     joe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  would not fact afraid snarl buster bear call thief everything bad could think buster do not seem mind chuckle think great joke repeat invitation little
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     joe come
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  get fish little
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     joe turn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  back go laugh brook great rage bad waste fine fish say buster thoughtfully wonder i d well wondering eat start laugh brook try catch little
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     joe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  otter get even buster bear little
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     joe otter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  terrible rage bad begin beautiful day little
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     joe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  know would not rage breakfast take ea
